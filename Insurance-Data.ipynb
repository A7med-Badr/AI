# %% [markdown]
# # insurance-data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read Uber dataset.csv.**

# %%
data = pd.read_csv('D:/insurance-data.csv')

# %% [markdown]
# **The number of columns and rows**

# %%
data.shape
# Out:
# (1338, 7)

# %% [markdown]
# **Use the .info() method to find out how many entries there are.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# **description of the data in the DataFrame.**

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# It looks like everything is within acceptable ranges.

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# **Return the last  rows.**

# %%
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %% [markdown]
# **Use the .isnull() method to find out ho null values.**

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# -------------------

# %% [markdown]
# **Comparing age to fees**

# %%
plt.figure(figsize = (18, 8))
sns.barplot(x = 'age', y = 'charges', data = data)
plt.title("Age vs Charges")
sns.despine()

# %% [markdown]
# As expected, charges go up with age.

# %% [markdown]
# ---------------------

# %% [markdown]
# **Fees are based on the number of children**

# %%
plt.figure(figsize = (18, 8))
sns.countplot(data['children'], palette = 'Blues_d').set_title('Distribution of Number of Children')
plt.xlabel('Number of Children')
plt.ylabel('Count')
sns.despine()
plt.show()
# Out:
# D:\anacoda3\co\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The number of children a member has an interesting impact on charges based on this plot: those with 2 or 3 kids have slightly higher charges than those with 0-1 or 4-5 kids.

# %% [markdown]
# ----------------

# %% [markdown]
# **The number of men and women**

# %%
colors = ['royalblue', 'pink']
labels = "Male", "Female"
size = (data['sex'].value_counts())
plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, data = data, colors = colors, labels = labels, shadow = True)
plt.title('Number of Male vs Female Members')
plt.show()

# %% [markdown]
# There are about the same number of males and females in this dataset.

# %% [markdown]
# ------------------

# %% [markdown]
# **The number of smokers and non-smokers, and a comparison of expenses**

# %%
colors = ['gray', 'green']
labels = "Smoker", "Non-Smoker"
size = (data['smoker'].value_counts())
plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, colors = colors, labels = labels, shadow = True)
plt.title('Number of Smoking vs Non-Smoking Members')
plt.show()

# %%
colors = ['gray', 'green']
plt.figure(figsize = (18, 6))
sns.scatterplot(x= 'age' , y= 'charges', hue='smoker', palette = colors, data=data).set_title('Charges vs Age Filtered by Smoking Status')
sns.despine()

# %% [markdown]
# Perhaps unsurprisingly, smokers consistently seem to have higher charges on average than non-smokers, independent of age.

# %% [markdown]
# --------------------

# %% [markdown]
# # Thanks 😊
